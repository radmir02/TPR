# %% [markdown]
# Задание 1. Обязательная часть Будем парсить страницу со свежеми новостям на habr.com/ru/all/.
#
# Вам необходимо собирать только те статьи, в которых встречается хотя бы одно требуемое ключевое слово. Эти слова определяем в начале кода в переменной, например:
#
# KEYWORDS = ['python', 'парсинг']
#
# Поиск вести по всей доступной preview-информации (это информация, доступная непосредственно с текущей страницы).
#
# В итоге должен формироваться датафрейм со столбцами: - - .

# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
import time

# %%
import regex

# %%
import pandas as pd

# %%
keywords = ['Python', 'python', 'Парсинг','парсинг']

# %%
URL = 'http://habr.com/ru/all/'

# %%
def get_all_info(url, keywords, pages):
    habr_posts = pd.DataFrame()
    
    for i in range(pages):
        params = 'page' + str(i + 1)
        res = requests.get(url+params)
        time.sleep(0.3)
        soup = BeautifulSoup(res.text, 'html.parser')
        title_blocks = soup.find_all('h2', class_='post__title')
        text_blocks = soup.find_all('div', class_='post__text post__text-html post__text_v1')
        time_block = soup.find_all('span', class_='post__time')
        all_titles = list(map(lambda x: x.find('a', class_='post__title_link').text, title_blocks))
        all_linkes = list(map(lambda x: x.find('a').get('href'), title_blocks))
        all_text = list(map(lambda x: x.get_text(),text_blocks))
        all_time = list(map(lambda x: x.get_text(), time_block))
        all_info = [list(tup) for tup in zip(all_time, all_titles, all_text, all_linkes)]
        for j in range(len(all_info)):
            if regex.search(r"\L<words>", all_info[j][1], words=keywords) or\
            regex.search(r"\L<words>", all_info[j][2], words=keywords):
                row = {'time': all_info[j][0], 'title': all_info[j][1], 'text': all_info[j][2], 'link': all_info[j][3]}
                habr_posts = pd.concat([habr_posts, pd.DataFrame([row])]) 
                 
    return habr_posts

all_links = get_all_info(URL, keywords, 30)
all_links
# Out:
#                       time                                              title  \
# 0          сегодня в 16:05  Attack-defence для бизнеса: разбираем задания ...
# 0          сегодня в 16:04  Вскрытие покажет: Решаем лёгкий crackme и пише...
# 0          сегодня в 15:54                        Побег из песочницы с Python
# 0            вчера в 23:54  Дайджест свежих материалов из мира фронтенда з...
# 0            вчера в 22:33  Шаблонные функции в Python, которые могут выпо...
# 0  29 октября 2020 в 18:29  Этичный хакинг: как взламывать системы и при э...
# 0  29 октября 2020 в 15:06            Как учить немецкий язык онлайн: месяц 1
# 0  28 октября 2020 в 11:34  Наш опыт с графовой базой данных Dgraph в Kube...
# 0  28 октября 2020 в 11:29                  Пишем бот для пазл игры на Python
# 0  28 октября 2020 в 11:18  Можно ли сложить N чисел типа double наиболее ...
# 0  27 октября 2020 в 23:51                     Какой тип числа у Number в JS?
# 0  26 октября 2020 в 21:35  Рудиментарные дела. Кого, чему, зачем и что не...
# 0  26 октября 2020 в 16:15  Создание камеры-ловушки с использованием Raspb...
# 0  26 октября 2020 в 07:52  Создаём установщик веб-приложения Python, вклю...
# 0  25 октября 2020 в 16:28                           Унарные операторы в Java
# 0  24 октября 2020 в 16:15  Почему 20-летний CRT-монитор лучше современног...
# 0  23 октября 2020 в 15:28  Почему без тимлида не обойтись: нюансы формиро...
# 0  22 октября 2020 в 16:27  Храним секреты в Linux: JWT аутентификация в C...
# 0  22 октября 2020 в 16:06  Герб Саттер о будущем С++, работе в комитете, ...
# 0  22 октября 2020 в 11:47  Мелкая питонячая радость #11: реактивное прогр...
#
#                                                 text  \
# 0  \n      Доброго времени суток читающий. Мне хо...
# 0  \nВ преддверии старта курса «Python Developer....
# 0  \n На прошлой неделе команда Google Project Ze...
# 0  \n\n\r\nСейчас практически каждый разработчик ...
# 0  \nПривет, Хабр! Меню зовут Юрий Богомолов, и в...
# 0  \n      В данной статье рассматривается ситуац...
# 0  \n      На конференции North Bay Python в 2018...
# 0  \n      Давно хотел попробовать свои силы в ко...
# 0  \nВ предыдущих сериях…\nПрошлая статья рассказ...
# 0  \n\n\r\nУ всех нас только и разговоров, что о ...
# 0  \n\r\nРеализуем и сравниваем 4 популярных опти...
# 0  \n      Привет, друзья! Хорошая новость для мо...
# 0  \nКаждый человек, который когда-либо сталкивал...
# 0  \n Перевод статьи подготовлен специально для с...
# 0  \n      Мне приходится работать с огромной код...
# 0  \n      Привет, Хабр.\n\r\nЧитатели старшего п...
# 0  \n\n\r\nОт тимлида зависит многое — эффективно...
# 0  \n      Привет, Хабр! Я в программировании уже...
# 0  \n\r\nСегодня делимся с вами переводом статьи ...
# 0  \n      В современных дата-центрах установлены...
#
#                                                 link
# 0    https://habr.com/ru/company/bizone/blog/525406/
# 0                   https://habr.com/ru/post/526136/
# 0      https://habr.com/ru/company/otus/blog/526132/
# 0                   https://habr.com/ru/post/526032/
# 0                   https://habr.com/ru/post/525998/
# 0  https://habr.com/ru/company/skillfactory/blog/...
# 0                   https://habr.com/ru/post/525624/
# 0     https://habr.com/ru/company/flant/blog/524750/
# 0                   https://habr.com/ru/post/525380/
# 0                   https://habr.com/ru/post/525090/
# 0                   https://habr.com/ru/post/525330/
# 0                   https://habr.com/ru/post/525168/
# 0     https://habr.com/ru/company/ruvds/blog/525016/
# 0                   https://habr.com/ru/post/525028/
# 0      https://habr.com/ru/company/otus/blog/524926/
# 0     https://habr.com/ru/company/ruvds/blog/524170/
# 0    https://habr.com/ru/company/mailru/blog/524752/
# 0                   https://habr.com/ru/post/524622/
# 0     https://habr.com/ru/company/jugru/blog/524600/
# 0                   https://habr.com/ru/post/523878/
